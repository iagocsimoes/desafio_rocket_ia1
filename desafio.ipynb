# %%
import pandas as pd

# %%
# Dicionário de faturamento
dict_faturamento = {
    'data_ref': [
        '2023-01-01', 
        '2020-02-01', 
        '2021-03-01', 
        '2022-04-01', 
        '2023-05-01',
        '2023-06-01', 
        '2020-07-01', 
        '2021-08-01', 
        '2022-09-01', 
        '2023-10-01',
        '2022-11-01', 
        '2023-12-01',
        ],
    'valor': [
        400000, 
        890000, 
        760000, 
        430000, 
        920000,
        340000, 
        800000, 
        500000, 
        200000, 
        900000,
        570000, 
        995000,
        ]
}

# %%
fat = pd.DataFrame(dict_faturamento)

# %%
fat
# Out:
#       data_ref   valor
# 0   2023-01-01  400000
# 1   2020-02-01  890000
# 2   2021-03-01  760000
# 3   2022-04-01  430000
# 4   2023-05-01  920000
# 5   2023-06-01  340000
# 6   2020-07-01  800000
# 7   2021-08-01  500000
# 8   2022-09-01  200000
# 9   2023-10-01  900000
# 10  2022-11-01  570000
# 11  2023-12-01  995000

# %%
fat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   data_ref  12 non-null     object
#  1   valor     12 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 320.0+ bytes

# %%
fat['data_ref'] = pd.to_datetime(fat['data_ref'])

# %%
# Media das vendas
fat.valor.mean()
# Out:
# 642083.3333333334

# %%
# Grafico de Barras Vertical
fat.sort_values('valor').plot.barh(x='data_ref',y='valor')
# Out:
# <Axes: ylabel='data_ref'>

# %%
# Grafico de Linha
fat.sort_values('valor').plot.line(x='valor',y='data_ref')
# Out:
# <Axes: xlabel='valor'>
